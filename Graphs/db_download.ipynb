# %%
import psycopg2
import pandas as pd
# Import postgres server info key
from postgres_info import user, password

try:
    # Connect to the database
    conn = psycopg2.connect(
        host="127.0.0.1",
        port="5432",
        user=user,
        password=password,
        database="ev_db"
    )
except psycopg2.Error as e:
    print("Error connecting to the database:")
    print(e)
else:
    print("Connection established successfully")
# Out:
# Connection established successfully

# %%
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Write your SQL queries
    cafv_query = "SELECT * FROM cafv_eligibility;"

    # Execute the query
    cursor.execute(cafv_query)
    # Fetch all rows from the result
    rows = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]
    cafv_df = pd.DataFrame(rows, columns=column_names)

except psycopg2.Error as e:
    print(f"Error: {e}")

# Close the cursor and the connection
cursor.close()

# Show dataframe
cafv_df
# Out:
#   cafv_id                                   cafv_eligibility
# 0   cafv1            Clean Alternative Fuel Vehicle Eligible
# 1   cafv2  Eligibility unknown as battery range has not b...
# 2   cafv3              Not eligible due to low battery range

# %%
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Write your SQL queries
    uc_query = "SELECT * FROM utility_companies;"

    # Execute the query
    cursor.execute(uc_query)
    # Fetch all rows from the result
    rows = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]
    uc_df = pd.DataFrame(rows, columns=column_names)

except psycopg2.Error as e:
    print(f"Error: {e}")

# Close the cursor and the connection
cursor.close()

# Show dataframe
uc_df
# Out:
#    utility_company_id                               utility_company_name
# 0               uc001       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 1               uc002                             PUGET SOUND ENERGY INC
# 2               uc003                                         PACIFICORP
# 3               uc004      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 4               uc005                           PUD NO 2 OF GRANT COUNTY
# ..                ...                                                ...
# 70              uc071  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF F...
# 71              uc072  BONNEVILLE POWER ADMINISTRATION||BENTON RURAL ...
# 72              uc073  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF A...
# 73              uc074  BONNEVILLE POWER ADMINISTRATION||NESPELEM VALL...
# 74              uc075  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...
#
# [75 rows x 2 columns]

# %%
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Write your SQL queries
    county_income_query = "SELECT * FROM county_income;"

    # Execute the query
    cursor.execute(county_income_query)
    # Fetch all rows from the result
    rows = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]
    income_df = pd.DataFrame(rows, columns=column_names)

except psycopg2.Error as e:
    print(f"Error: {e}")

# Close the cursor and the connection
cursor.close()

# Show dataframe
income_df
# Out:
#      fips_code income_year percapita_income      county state
# 0        01001        2022         29749.89     Autauga    AL
# 1        01003        2022        142052.69     Baldwin    AL
# 2        01005        2022         10134.59     Barbour    AL
# 3        01007        2022          8397.82        Bibb    AL
# 4        01009        2022         26224.26      Blount    AL
# ...        ...         ...              ...         ...   ...
# 3135     56037        2022         24871.85  Sweetwater    WY
# 3136     56039        2022         97537.41       Teton    WY
# 3137     56041        2022          9617.53       Uinta    WY
# 3138     56043        2022          4229.05    Washakie    WY
# 3139     56045        2022          3503.78      Weston    WY
#
# [3140 rows x 5 columns]

# %%
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Write your SQL queries
    location_query = "SELECT * FROM location_info;"

    # Execute the query
    cursor.execute(location_query)
    # Fetch all rows from the result
    rows = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]
    location_df = pd.DataFrame(rows, columns=column_names)

except psycopg2.Error as e:
    print(f"Error: {e}")

# Close the cursor and the connection
cursor.close()

# Show dataframe
location_df
# Out:
#     postal_code fips_code       county               city state  \
# 0         99403     53003       Asotin          Clarkston    WA
# 1         99402     53003       Asotin             Asotin    WA
# 2         99371     53001        Adams          Washtucna    WA
# 3         99362     53071  Walla Walla        Walla Walla    WA
# 4         99361     53071  Walla Walla          Waitsburg    WA
# ..          ...       ...          ...                ...   ...
# 908       12866     36091     Saratoga   Saratoga Springs    NY
# 909       12833     36091     Saratoga  Greenfield Center    NY
# 910       11572     36059       Nassau          Oceanside    NY
# 911       11209     36047        Kings           Brooklyn    NY
# 912       10023     36061     New York           New York    NY
#
#     legislative_district   latitude    longitude census_tract_2020
# 0                      9  46.414020  -117.045560       53003960300
# ...

# %%
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Write your SQL query
    vehicle_types_query = "SELECT * FROM vehicle_types;"

    # Execute the query
    cursor.execute(vehicle_types_query)
    # Fetch all rows from the result
    rows = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]
    vehicle_types_df = pd.DataFrame(rows, columns=column_names)

except psycopg2.Error as e:
    print(f"Error: {e}")

# Close the cursor and the connection
cursor.close()

# Show dataframe
vehicle_types_df
# Out:
#     vehicle_type_id model_year    make     model  \
# 0            vm0001       1999    FORD    RANGER
# 1            vm0002       2000    FORD    RANGER
# 2            vm0003       2002  TOYOTA      RAV4
# 3            vm0004       2003  TOYOTA      RAV4
# 4            vm0005       2008   TESLA  ROADSTER
# ..              ...        ...     ...       ...
# 553          vm0554       2025   VOLVO      EX40
# 554          vm0555       2025   VOLVO       S60
# 555          vm0556       2025   VOLVO       V60
# 556          vm0557       2025   VOLVO      XC60
# 557          vm0558       2025   VOLVO      XC90
#
#                                     ev_type
# 0            Battery Electric Vehicle (BEV)
# 1            Battery Electric Vehicle (BEV)
# 2            Battery Electric Vehicle (BEV)
# 3            Battery Electric Vehicle (BEV)
# 4            Battery Electric Vehicle (BEV)
# ..                                      ...
# 553          Battery Electric Vehicle (BEV)
# ...

# %%
try:
    # Create a cursor object
    cursor = conn.cursor()

    # Write your SQL query
    vehicles_query = "SELECT * FROM vehicles;"

    # Execute the query
    cursor.execute(vehicles_query)
    # Fetch all rows from the result
    rows = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]
    vehicles_df = pd.DataFrame(rows, columns=column_names)

except psycopg2.Error as e:
    print(f"Error: {e}")

# Close the cursor and the connection
cursor.close()

vehicles_df
# Out:
#        dol_vehicle_id vehicle_type_id postal_code fips_code  \
# 0           125450447          vm0027       98177     53033
# 1           101662900          vm0199       98112     53033
# 2           272118717          vm0288       98359     53035
# 3           349372929          vm0129       98501     53067
# 4           171625653          vm0081       98506     53067
# ...               ...             ...         ...       ...
# 216735      122822822          vm0021       98802     53017
# 216736      267143887          vm0479       98229     53073
# 216737      274988388          vm0518       98052     53033
# 216738      117353064          vm0021       98329     53053
# 216739      240754006          vm0420       98391     53053
#
#        utility_company_id cafv_id         vin electric_range base_msrp
# 0                   uc001   cafv1  1N4AZ0CP8D           75.0      0.00
# 1                   uc001   cafv1  5YJSA1E45K          270.0      0.00
# ...

# %%
# Close connection
conn.close()
